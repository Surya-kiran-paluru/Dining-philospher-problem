# %%
import threading
import random
import time
 
class Philosopher(threading.Thread):
 
    running = True
 
    def __init__(self, xname, forkOnLeft, forkOnRight):
        threading.Thread.__init__(self)
        self.name = xname
        self.forkOnLeft = forkOnLeft
        self.forkOnRight = forkOnRight
 
    def run(self):
        while(self.running):
            #  Philosopher is thinking (but really is sleeping).
            time.sleep( random.uniform(3,13))
            print ('{} is hungry.'.format(self.name))
            self.dine()
 
    def dine(self):
        fork1, fork2 = self.forkOnLeft, self.forkOnRight
 
        while self.running:
            fork1.acquire(True)
            locked = fork2.acquire(False)
            if locked: break
            fork1.release()
            print ('{} swaps forks'.format(self.name))
            fork1, fork2 = fork2, fork1
        else:
            return
 
        self.dining()
        fork2.release()
        fork1.release()
 
    def dining(self):			
        print ('{} starts eating'.format(self.name))
        time.sleep(random.uniform(1,10))
        print ('{} finishes eating and leaves to think.'.format(self.name))
 
def DiningPhilosophers():
    forks = [threading.Lock() for n in range(5)]
    philosopherNames = ('1','2','3','4', '5')
 
    philosophers= [Philosopher(philosopherNames[i], forks[i%5], forks[(i+1)%5]) \
            for i in range(5)]
 
    random.seed(507129)
    Philosopher.running = True
    for p in philosophers: p.start()
    time.sleep(100)
    Philosopher.running = False
    print ("Now we're finishing.")
 
DiningPhilosophers()
# Out:
# 3 finishes eating and leaves to think.
# 4 is hungry.
# 4 starts eating
# 1 finishes eating and leaves to think.
# 5 swaps forks
# 4 finishes eating and leaves to think.
# 5 starts eating
# 2 is hungry.
# 2 starts eating
# 2 finishes eating and leaves to think.
# 4 is hungry.
# 4 swaps forks
# 3 is hungry.
# 3 starts eating
# 5 finishes eating and leaves to think.
# 4 swaps forks
# 1 is hungry.
# 1 starts eating
# 1 finishes eating and leaves to think.
# 2 is hungry.
# 2 swaps forks
# 3 finishes eating and leaves to think.
# 4 starts eating2 starts eating
#
# 4 finishes eating and leaves to think.
# 5 is hungry.
# 5 starts eating
# 5 finishes eating and leaves to think.
# 2 finishes eating and leaves to think.
# 1 is hungry.
# 1 starts eating
# 2 is hungry.
# 3 is hungry.
# 3 starts eating
# 4 is hungry.
# 5 is hungry.
# 5 swaps forks
# 3 finishes eating and leaves to think.
# 4 starts eating
# 1 finishes eating and leaves to think.
# 5 swaps forks2 starts eating
#
# 4 finishes eating and leaves to think.
# 5 starts eating
# 2 finishes eating and leaves to think.
# 1 is hungry.
# 3 is hungry.
# 3 starts eating
# 5 finishes eating and leaves to think.
# 1 starts eating
# 4 is hungry.
# 3 finishes eating and leaves to think.
# 4 starts eating
# 2 is hungry.
# 4 finishes eating and leaves to think.
# 1 finishes eating and leaves to think.
# 2 starts eating
# 3 is hungry.
# 5 is hungry.
# 5 starts eating
# 5 finishes eating and leaves to think.
# 2 finishes eating and leaves to think.
# 3 starts eating
# 1 is hungry.
# 1 starts eating
# 4 is hungry.
# 5 is hungry.
# 5 swaps forks
# 3 finishes eating and leaves to think.
# 4 starts eating
# 1 finishes eating and leaves to think.
# 5 swaps forks
# 2 is hungry.
# 2 starts eating
# 1 is hungry.
# 1 swaps forks
# 2 finishes eating and leaves to think.
# 1 starts eating
# 4 finishes eating and leaves to think.
# 5 swaps forks
# 3 is hungry.
# 3 starts eating
# 3 finishes eating and leaves to think.
# 1 finishes eating and leaves to think.
# 5 starts eating
# 4 is hungry.
# 4 swaps forks
# 2 is hungry.
# 2 starts eating
# 3 is hungry.
# 1 is hungry.
# 5 finishes eating and leaves to think.
# 4 starts eating
# 1 swaps forks
# 2 finishes eating and leaves to think.
# 1 starts eating
# 3 swaps forks
# 5 is hungry.
# 4 finishes eating and leaves to think.
# 5 swaps forks3 starts eating
#
# 1 finishes eating and leaves to think.
# 5 starts eating
# 1 is hungry.
# 2 is hungry.
# 2 swaps forks
# 3 finishes eating and leaves to think.
# 2 starts eating
# 4 is hungry.
# 4 swaps forks
# 5 finishes eating and leaves to think.
# 1 swaps forks
# 4 starts eating
# 2 finishes eating and leaves to think.
# 1 starts eating
# 1 finishes eating and leaves to think.
# 4 finishes eating and leaves to think.
# 5 is hungry.
# 5 starts eating
# 1 is hungry.
# 2 is hungry.
# 2 starts eating
# 3 is hungry.
# 4 is hungry.
# 4 swaps forks
# 2 finishes eating and leaves to think.
# 3 starts eating
# 5 finishes eating and leaves to think.
# 1 starts eating4 swaps forks
#
# 1 finishes eating and leaves to think.
# 3 finishes eating and leaves to think.
# 4 starts eating
# 1 is hungry.
# 1 starts eating
# 5 is hungry.
# 2 is hungry.
# 3 is hungry.
# 3 swaps forks
# 4 finishes eating and leaves to think.
# 5 swaps forks3 starts eating
#
# 1 finishes eating and leaves to think.
# 2 swaps forks5 starts eating
#
# 5 finishes eating and leaves to think.
# 3 finishes eating and leaves to think.
# 2 starts eating
# 5 is hungry.
# 5 starts eating
# 4 is hungry.
# 4 swaps forks
# 2 finishes eating and leaves to think.
# 1 is hungry.
# 5 finishes eating and leaves to think.
# 4 starts eating1 starts eating
#
# 1 finishes eating and leaves to think.
# 3 is hungry.
# 3 swaps forks
# 4 finishes eating and leaves to think.
# 3 starts eating
# 1 is hungry.
# 1 starts eating
# 3 finishes eating and leaves to think.
# 5 is hungry.
# 5 swaps forks
# 1 finishes eating and leaves to think.
# 5 starts eating
# 2 is hungry.
# 2 starts eating
# 4 is hungry.
# 4 swaps forks
# 3 is hungry.
# 5 finishes eating and leaves to think.
# 4 starts eating
# 2 finishes eating and leaves to think.
# 3 swaps forks
# 1 is hungry.
# 1 starts eating
# 4 finishes eating and leaves to think.
# 3 starts eating
# 1 finishes eating and leaves to think.
# 5 is hungry.
# 5 starts eating
# 2 is hungry.
# 2 swaps forks
# 3 finishes eating and leaves to think.
# 2 starts eating
# 4 is hungry.
# 4 swaps forks
# 1 is hungry.
# 5 finishes eating and leaves to think.
# 4 starts eating
# 1 swaps forks
# 2 finishes eating and leaves to think.
# 1 starts eating
# 3 is hungry.
# 3 swaps forks
# 5 is hungry.
# 4 finishes eating and leaves to think.
# 5 swaps forks3 starts eating
#
# 1 finishes eating and leaves to think.
# 5 starts eating
# 3 finishes eating and leaves to think.
# 2 is hungry.
# 2 starts eating
# 1 is hungry.
# 2 finishes eating and leaves to think.
# 5 finishes eating and leaves to think.
# 1 starts eating
# 3 is hungry.
# 3 starts eating
# 4 is hungry.
# 2 is hungry.
# 1 finishes eating and leaves to think.
# 2 swaps forks
# 3 finishes eating and leaves to think.
# 2 starts eating4 starts eating
#
# 4 finishes eating and leaves to think.
# 1 is hungry.
# 1 swaps forks
# 2 finishes eating and leaves to think.
# 1 starts eating
# 5 is hungry.
# 5 swaps forks
# 3 is hungry.
# 3 starts eating
# 3 finishes eating and leaves to think.
# 1 finishes eating and leaves to think.
# 5 starts eating
# 4 is hungry.
# 4 swaps forks
# 5 finishes eating and leaves to think.
# 4 starts eating
# 2 is hungry.
# 2 starts eating
# 1 is hungry.
# 1 swaps forks
# 5 is hungry.
# 2 finishes eating and leaves to think.
# 1 starts eating
# 3 is hungry.
# 3 swaps forks
# 4 finishes eating and leaves to think.
# 5 swaps forks3 starts eating
#
# 3 finishes eating and leaves to think.
# 1 finishes eating and leaves to think.
# 5 starts eating
# 2 is hungry.
# 2 starts eating
# 4 is hungry.
# 4 swaps forks
# 5 finishes eating and leaves to think.
# 4 starts eating
# 4 finishes eating and leaves to think.
# 3 is hungry.
# 1 is hungry.
# 1 swaps forks
# 2 finishes eating and leaves to think.
# 1 starts eating3 starts eating
#
# 1 finishes eating and leaves to think.
# 2 is hungry.
# 2 swaps forks
# 3 finishes eating and leaves to think.
# 2 starts eating
# 1 is hungry.
# 1 swaps forks
# 5 is hungry.
# 5 starts eating
# 4 is hungry.
# 4 swaps forks
# 2 finishes eating and leaves to think.
# 1 swaps forks
# 3 is hungry.
# 3 starts eating
# 5 finishes eating and leaves to think.
# 4 swaps forks1 starts eating
#
# 1 finishes eating and leaves to think.
# 3 finishes eating and leaves to think.
# 4 starts eating
# 2 is hungry.
# 2 starts eating
# 5 is hungry.
# 4 finishes eating and leaves to think.
# 5 starts eating
# 1 is hungry.
# 2 finishes eating and leaves to think.
# 3 is hungry.
# 3 starts eating
# 4 is hungry.
# 5 finishes eating and leaves to think.
# 1 starts eating
# 3 finishes eating and leaves to think.
# 4 starts eating
# 1 finishes eating and leaves to think.
# 2 is hungry.
# 2 starts eating
# 1 is hungry.
# 1 swaps forks
# 3 is hungry.
# 4 finishes eating and leaves to think.
# 2 finishes eating and leaves to think.
# 1 starts eating3 starts eating
#
# 3 finishes eating and leaves to think.
# 5 is hungry.
# 5 swaps forks
# 2 is hungry.
# 1 finishes eating and leaves to think.
# 2 starts eating5 starts eating
#
# 2 finishes eating and leaves to think.
# 5 finishes eating and leaves to think.
# 4 is hungry.
# 4 starts eating
# 3 is hungry.
# 3 swaps forks
# 2 is hungry.
# 2 starts eating
# 1 is hungry.
# 1 swaps forks
# 4 finishes eating and leaves to think.
# 3 swaps forks
# 2 finishes eating and leaves to think.
# 1 starts eating
# 3 starts eating
# 5 is hungry.
# 5 swaps forks
# 1 finishes eating and leaves to think.
# 5 starts eating
# 2 is hungry.
# 2 swaps forks
# 3 finishes eating and leaves to think.
# 2 starts eating
# 5 finishes eating and leaves to think.
# 1 is hungry.
# 1 swaps forks
# 2 finishes eating and leaves to think.
# 1 starts eating
# 4 is hungry.
# 4 starts eating
# 4 finishes eating and leaves to think.
# 5 is hungry.
# 5 swaps forks
# 3 is hungry.
# 3 starts eating
# 3 finishes eating and leaves to think.
# 1 finishes eating and leaves to think.
# 5 starts eating
# 4 is hungry.
# 4 swaps forks
# 2 is hungry.
# 2 starts eating
# 1 is hungry.
# 5 finishes eating and leaves to think.
# 1 swaps forks4 starts eating
#
# 3 is hungry.
# 2 finishes eating and leaves to think.
# 1 starts eating3 swaps forks
#
# 5 is hungry.
# 4 finishes eating and leaves to think.
# 3 starts eating
# 5 swaps forks
# 2 is hungry.
# 3 finishes eating and leaves to think.
# 1 finishes eating and leaves to think.
# 2 starts eating
# 5 starts eating
# 2 finishes eating and leaves to think.
# 4 is hungry.
# 4 swaps forks
# 5 finishes eating and leaves to think.
# 4 starts eating
# 1 is hungry.
# 1 starts eating
# 1 finishes eating and leaves to think.
# 3 is hungry.
# 3 swaps forks
# 4 finishes eating and leaves to think.
# 3 starts eating
# 2 is hungry.
# 2 swaps forks
# 5 is hungry.
# 5 starts eating
# 5 finishes eating and leaves to think.
# 4 is hungry.
# 3 finishes eating and leaves to think.
# 2 starts eating4 starts eating
#
# 5 is hungry.
# 1 is hungry.
# 1 swaps forks
# 4 finishes eating and leaves to think.
# 5 starts eating
# 3 is hungry.
# 2 finishes eating and leaves to think.
# 3 starts eating1 swaps forks
#
# 5 finishes eating and leaves to think.
# 1 starts eating
# 4 is hungry.
# 1 finishes eating and leaves to think.
# 2 is hungry.
# 2 swaps forks
# 3 finishes eating and leaves to think.
# 4 starts eating2 starts eating
#
# 5 is hungry.
# 1 is hungry.
# 1 swaps forks
# 2 finishes eating and leaves to think.
# 1 starts eating
# 3 is hungry.
# 3 swaps forks
# 4 finishes eating and leaves to think.
# 5 swaps forks3 starts eating
#
# 3 finishes eating and leaves to think.
# 1 finishes eating and leaves to think.
# 5 starts eating
# 2 is hungry.
# 2 starts eating
# 4 is hungry.
# 4 swaps forks
# 3 is hungry.
# 5 finishes eating and leaves to think.
# 4 starts eating
# 1 is hungry.
# 1 swaps forks
# 4 finishes eating and leaves to think.
# 2 finishes eating and leaves to think.
# 1 starts eating3 starts eating
#
# 5 is hungry.
# 5 swaps forks
# 1 finishes eating and leaves to think.
# 5 starts eating
# 4 is hungry.
# 3 finishes eating and leaves to think.
# 4 swaps forks
# 1 is hungry.
# 2 is hungry.
# 2 starts eating
# 5 finishes eating and leaves to think.
# 1 swaps forks4 starts eating
#
# 2 finishes eating and leaves to think.
# 1 starts eating
# 3 is hungry.
# 3 swaps forks
# 4 finishes eating and leaves to think.
# 3 starts eating
# 1 finishes eating and leaves to think.
# 5 is hungry.
# 5 starts eating
# 2 is hungry.
# 2 swaps forks
# 3 finishes eating and leaves to think.
# 2 starts eating
# 1 is hungry.
# 4 is hungry.
# 4 swaps forks
# 5 finishes eating and leaves to think.
# 4 starts eating
# 1 swaps forks
# 3 is hungry.
# 2 finishes eating and leaves to think.
# 3 swaps forks1 starts eating
#
# 4 finishes eating and leaves to think.
# 3 starts eating
# 2 is hungry.
# 5 is hungry.
# 5 swaps forks
# 1 finishes eating and leaves to think.
# 2 swaps forks5 starts eating
#
# 4 is hungry.
# 5 finishes eating and leaves to think.
# 3 finishes eating and leaves to think.
# 2 starts eating4 starts eating
#
# 4 finishes eating and leaves to think.
# 5 is hungry.
# 5 starts eating
# 3 is hungry.
# 2 finishes eating and leaves to think.
# 3 starts eating
# 1 is hungry.
# 5 finishes eating and leaves to think.
# 1 starts eating
# 4 is hungry.
# 1 finishes eating and leaves to think.
# 3 finishes eating and leaves to think.
# 4 starts eating
# 4 finishes eating and leaves to think.
# 2 is hungry.
# 2 starts eating
# 5 is hungry.
# 5 starts eating
# 1 is hungry.
# 4 is hungry.
# 4 swaps forks
# 5 finishes eating and leaves to think.
# 4 starts eating
# 1 swaps forks
# 3 is hungry.
# 4 finishes eating and leaves to think.
# 2 finishes eating and leaves to think.
# 1 starts eating3 starts eating
#
# 4 is hungry.
# 5 is hungry.
# 5 swaps forks
# 3 finishes eating and leaves to think.
# 4 starts eating
# 1 finishes eating and leaves to think.
# 5 swaps forks
# 4 finishes eating and leaves to think.
# 5 starts eating
# 3 is hungry.
# 3 starts eating
# 5 finishes eating and leaves to think.
# 2 is hungry.
# 2 swaps forks
# 3 finishes eating and leaves to think.
# 2 starts eating
# 1 is hungry.
# 1 swaps forks
# 4 is hungry.
# 4 starts eating
# 3 is hungry.
# 2 finishes eating and leaves to think.
# 1 starts eating
# 3 swaps forks
# 5 is hungry.
# 1 finishes eating and leaves to think.
# 4 finishes eating and leaves to think.
# 3 starts eating5 starts eating
#
# 2 is hungry.
# 2 swaps forks
# 1 is hungry.
# 5 finishes eating and leaves to think.
# 1 starts eating
# 3 finishes eating and leaves to think.
# 2 swaps forks
# 4 is hungry.
# 4 starts eating
# 1 finishes eating and leaves to think.
# 2 starts eating
# 3 is hungry.
# 2 finishes eating and leaves to think.
# 3 swaps forks
# 4 finishes eating and leaves to think.
# 3 starts eating
# 1 is hungry.
# 1 starts eating
# 5 is hungry.
# 5 swaps forks
# 1 finishes eating and leaves to think.
# 5 starts eating
# 3 finishes eating and leaves to think.
# 4 is hungry.
# 4 swaps forks
# 2 is hungry.
# 2 starts eating
# 3 is hungry.
# 1 is hungry.
# 5 finishes eating and leaves to think.
# 4 starts eating1 swaps forks
#
# 4 finishes eating and leaves to think.
# 2 finishes eating and leaves to think.
# 1 starts eating3 starts eating
#
# 4 is hungry.
# 2 is hungry.
# 5 is hungry.
# 5 swaps forks
# 3 finishes eating and leaves to think.
# 4 starts eating
# 1 finishes eating and leaves to think.
# 2 starts eating5 swaps forks
#
# 4 finishes eating and leaves to think.
# 5 starts eating
# 5 finishes eating and leaves to think.
# 2 finishes eating and leaves to think.
# 3 is hungry.
# 3 starts eating
# 1 is hungry.
# 1 starts eating
# 5 is hungry.
# 5 swaps forks
# 4 is hungry.
# 1 finishes eating and leaves to think.
# 5 starts eating
# 2 is hungry.
# 2 swaps forks
# 3 finishes eating and leaves to think.
# 4 swaps forks2 starts eating
#
# 2 finishes eating and leaves to think.
# 5 finishes eating and leaves to think.
# 4 starts eating
# 3 is hungry.
# 3 swaps forks
# 2 is hungry.
# 2 starts eating
# 5 is hungry.
# 1 is hungry.
# 1 swaps forks
# 4 finishes eating and leaves to think.
# 5 starts eating3 swaps forks
#
# 5 finishes eating and leaves to think.
# 4 is hungry.
# 4 starts eating
# 2 finishes eating and leaves to think.
# 1 starts eating3 swaps forks
#
# 4 finishes eating and leaves to think.
# 3 starts eating
# 5 is hungry.
# 5 swaps forks
# 3 finishes eating and leaves to think.
# 2 is hungry.
# 1 finishes eating and leaves to think.
# 2 starts eating
# 5 starts eating
# 2 finishes eating and leaves to think.
# 1 is hungry.
# 5 finishes eating and leaves to think.
# 1 starts eating
# 4 is hungry.
# 4 starts eating
# 5 is hungry.
# 4 finishes eating and leaves to think.
# 5 swaps forks
# 1 finishes eating and leaves to think.
# 5 starts eating
# 3 is hungry.
# 3 starts eating
# 2 is hungry.
# 2 swaps forks
# 1 is hungry.
# 5 finishes eating and leaves to think.
# 1 starts eating
# 3 finishes eating and leaves to think.
# 2 swaps forks
# 1 finishes eating and leaves to think.
# 2 starts eating
# 4 is hungry.
# 4 starts eating
# 3 is hungry.
# 2 finishes eating and leaves to think.
# 3 swaps forks
# 4 finishes eating and leaves to think.
# 3 starts eating
# 1 is hungry.
# 1 starts eating
# 2 is hungry.
# 5 is hungry.
# 5 swaps forks
# 1 finishes eating and leaves to think.
# 5 starts eating2 swaps forks
#
# 3 finishes eating and leaves to think.
# 2 starts eating
# 4 is hungry.
# 4 swaps forks
# 1 is hungry.
# 5 finishes eating and leaves to think.
# 1 swaps forks4 starts eating
#
# 4 finishes eating and leaves to think.
# 2 finishes eating and leaves to think.
# 1 starts eating
# 3 is hungry.
# 3 starts eating
# 4 is hungry.
# 1 finishes eating and leaves to think.
# 5 is hungry.
# 5 starts eating
# 3 finishes eating and leaves to think.
# 4 swaps forks
# 5 finishes eating and leaves to think.
# 4 starts eating
# 2 is hungry.
# 2 starts eating
# 5 is hungry.
# 4 finishes eating and leaves to think.
# 5 starts eating
# 2 finishes eating and leaves to think.
# 1 is hungry.
# 3 is hungry.
# 3 starts eating
# 2 is hungry.
# 2 swaps forks
# 5 finishes eating and leaves to think.
# 1 starts eating
# 3 finishes eating and leaves to think.
# 2 swaps forks
# 4 is hungry.
# 4 starts eating
# 4 finishes eating and leaves to think.
# 1 finishes eating and leaves to think.
# 2 starts eating
# 3 is hungry.
# 4 is hungry.
# 4 starts eating
# 5 is hungry.
# 4 finishes eating and leaves to think.
# 5 starts eating
# 2 finishes eating and leaves to think.
# 3 starts eating
# 5 finishes eating and leaves to think.
# 2 is hungry.
# 2 swaps forks
# 1 is hungry.
# 1 starts eating
# 4 is hungry.
# 3 finishes eating and leaves to think.
# 4 starts eating2 swaps forks
#
# 1 finishes eating and leaves to think.
# 2 starts eating
# 5 is hungry.
# 4 finishes eating and leaves to think.
# 5 starts eating
# 3 is hungry.
# 2 finishes eating and leaves to think.
# 3 starts eating
# 1 is hungry.
# 5 finishes eating and leaves to think.
# 1 starts eating
# 3 finishes eating and leaves to think.
# 4 is hungry.
# 4 starts eating
# 2 is hungry.
# 3 is hungry.
# 3 swaps forks
# 4 finishes eating and leaves to think.
# 3 starts eating
# 5 is hungry.
# 5 swaps forks
# 1 finishes eating and leaves to think.
# 5 starts eating2 swaps forks
#
# 4 is hungry.
# 5 finishes eating and leaves to think.
# 3 finishes eating and leaves to think.
# 2 starts eating4 starts eating
#
# 4 finishes eating and leaves to think.
# 1 is hungry.
# 1 swaps forks
# 3 is hungry.
# 2 finishes eating and leaves to think.
# 1 starts eating3 starts eating
# 5 is hungry.
# 5 swaps forks
# 1 finishes eating and leaves to think.
# 5 starts eating
# 3 finishes eating and leaves to think.
# 4 is hungry.
# 4 swaps forks
# 5 finishes eating and leaves to think.
# 4 starts eating
# 1 is hungry.
# 1 starts eating
# 3 is hungry.
# 3 swaps forks
# 2 is hungry.
# 4 finishes eating and leaves to think.
# 3 starts eating
# 5 is hungry.
# 5 swaps forks
# 3 finishes eating and leaves to think.
# 1 finishes eating and leaves to think.
# 2 starts eating5 starts eating
#
# 3 is hungry.
# 2 finishes eating and leaves to think.
# 3 starts eating
# 5 finishes eating and leaves to think.
# 4 is hungry.
# 3 finishes eating and leaves to think.
# 4 starts eating
# 1 is hungry.
# 1 starts eating
# 4 finishes eating and leaves to think.
# 2 is hungry.
# 5 is hungry.
# 5 swaps forks
# 3 is hungry.
# 3 starts eating
# 1 finishes eating and leaves to think.
# 5 starts eating2 swaps forks
#
# 3 finishes eating and leaves to think.
# 2 starts eating
# 4 is hungry.
# 4 swaps forks
# 5 finishes eating and leaves to think.
# 4 starts eating
# 2 finishes eating and leaves to think.
# 4 finishes eating and leaves to think.
# 3 is hungry.
# 3 starts eating
# 1 is hungry.
# 1 starts eating
# 3 finishes eating and leaves to think.
# 5 is hungry.
# 5 swaps forks
# 1 finishes eating and leaves to think.
# 5 starts eating
# 4 is hungry.
# 4 swaps forks
# 2 is hungry.
# 2 starts eating
# 1 is hungry.
# 2 finishes eating and leaves to think.
# 5 finishes eating and leaves to think.
# 4 starts eating
# 1 starts eating
# 3 is hungry.
# 3 swaps forks
# 2 is hungry.
# 4 finishes eating and leaves to think.
# 3 starts eating
# 1 finishes eating and leaves to think.
# 2 swaps forks
# 5 is hungry.
# 5 starts eating
# 3 finishes eating and leaves to think.
# 2 starts eating
# 5 finishes eating and leaves to think.
# 3 is hungry.
# 1 is hungry.
# 1 swaps forks
# 2 finishes eating and leaves to think.
# 3 starts eating1 starts eating
#
# 4 is hungry.
# 5 is hungry.
# 5 swaps forks
# 1 finishes eating and leaves to think.
# 5 starts eating
# 3 finishes eating and leaves to think.
# 4 swaps forks
# 2 is hungry.
# 2 starts eating
# 5 finishes eating and leaves to think.
# 4 starts eating
# 4 finishes eating and leaves to think.
# 2 finishes eating and leaves to think.
# 1 is hungry.
# 1 starts eating
# 3 is hungry.
# 3 starts eating
# 1 finishes eating and leaves to think.
# 4 is hungry.
# 3 finishes eating and leaves to think.
# 4 starts eating
# 5 is hungry.
# 4 finishes eating and leaves to think.
# 5 starts eating
# 1 is hungry.
# 2 is hungry.
# 2 starts eating
# 5 finishes eating and leaves to think.
# 1 swaps forks
# 2 finishes eating and leaves to think.
# 1 starts eating
# 3 is hungry.
# 3 starts eating
# 1 finishes eating and leaves to think.
# 4 is hungry.
# 3 finishes eating and leaves to think.
# 4 starts eating
# 5 is hungry.
# 2 is hungry.
# 2 starts eating
# 4 finishes eating and leaves to think.
# 5 starts eating
# 1 is hungry.
# 3 is hungry.
# 2 finishes eating and leaves to think.
# 3 starts eating
# 5 finishes eating and leaves to think.
# 1 starts eating
# 1 finishes eating and leaves to think.
# 2 is hungry.
# 2 swaps forks
# 3 finishes eating and leaves to think.
# 2 starts eating
# 1 is hungry.
# 1 swaps forks
# 4 is hungry.
# 4 starts eating
# 2 finishes eating and leaves to think.
# 1 starts eating
# 5 is hungry.
# 4 finishes eating and leaves to think.
# 5 swaps forks
# 3 is hungry.
# 3 starts eating
# 1 finishes eating and leaves to think.
# 5 starts eating
# 4 is hungry.
# 1 is hungry.
# 2 is hungry.
# 2 swaps forks
# 5 finishes eating and leaves to think.
# 1 starts eating
# 3 finishes eating and leaves to think.
# 2 swaps forks4 starts eating
#
# 4 finishes eating and leaves to think.
# 3 is hungry.
# 3 starts eating
# 3 finishes eating and leaves to think.
# 5 is hungry.
# 5 swaps forks
# 1 finishes eating and leaves to think.
# 5 starts eating2 starts eating
#
# 4 is hungry.
# 4 swaps forks
# 2 finishes eating and leaves to think.
# 5 finishes eating and leaves to think.
# 4 starts eating
# 3 is hungry.
# 3 swaps forks
# 1 is hungry.
# 1 starts eating
# 4 finishes eating and leaves to think.
# 3 starts eating
# 3 finishes eating and leaves to think.
# 5 is hungry.
# 5 swaps forks
# 1 finishes eating and leaves to think.
# 5 starts eating
# 2 is hungry.
# 2 starts eating
# 2 finishes eating and leaves to think.
# 5 finishes eating and leaves to think.
# 4 is hungry.
# 4 starts eating
# 3 is hungry.
# 3 swaps forks
# 2 is hungry.
# 2 starts eating
# 4 finishes eating and leaves to think.
# 3 swaps forks
# 1 is hungry.
# 1 swaps forks
# 2 finishes eating and leaves to think.
# 3 starts eating1 starts eating
#
# 3 finishes eating and leaves to think.
# 5 is hungry.
# 5 swaps forks
# 2 is hungry.
# 3 is hungry.
# 3 starts eating
# 1 finishes eating and leaves to think.
# 5 starts eating2 swaps forks
#
# 4 is hungry.
# 3 finishes eating and leaves to think.
# 4 swaps forks2 starts eating
#
# 5 finishes eating and leaves to think.
# 4 starts eating
# 1 is hungry.
# 1 swaps forks
# 2 finishes eating and leaves to think.
# 1 starts eating
# 5 is hungry.
# 1 finishes eating and leaves to think.
# 4 finishes eating and leaves to think.
# 5 starts eating
# 3 is hungry.
# 3 starts eating
# 4 is hungry.
# 5 finishes eating and leaves to think.
# 3 finishes eating and leaves to think.
# 4 starts eating
# 1 is hungry.
# 1 starts eating
# 2 is hungry.
# 4 finishes eating and leaves to think.
# 3 is hungry.
# 3 starts eating
# 1 finishes eating and leaves to think.
# 2 swaps forks
# 1 is hungry.
# 1 starts eating
# 3 finishes eating and leaves to think.
# 2 swaps forks
# 4 is hungry.
# 4 starts eating
# 5 is hungry.
# 3 is hungry.
# 3 swaps forks
# 1 finishes eating and leaves to think.
# 2 starts eating
# 4 finishes eating and leaves to think.
# 3 swaps forks5 starts eating
#
# 1 is hungry.
# 5 finishes eating and leaves to think.
# 1 swaps forks
# 2 finishes eating and leaves to think.
# 3 starts eating1 starts eating
#
# 5 is hungry.
# 5 swaps forks
# 2 is hungry.
# 1 finishes eating and leaves to think.
# 2 swaps forks5 starts eating
#
# 4 is hungry.
# 3 finishes eating and leaves to think.
# 2 starts eating
# 4 swaps forks
# 2 finishes eating and leaves to think.
# 5 finishes eating and leaves to think.
# 4 starts eating
# 3 is hungry.
# 3 swaps forks
# 5 is hungry.
# 2 is hungry.
# 2 starts eating
# 4 finishes eating and leaves to think.
# 5 starts eating3 swaps forks
#
# 2 finishes eating and leaves to think.
# 3 starts eating
# 1 is hungry.
# 4 is hungry.
# 5 finishes eating and leaves to think.
# 1 starts eating
# 3 finishes eating and leaves to think.
# 4 starts eating
# 1 finishes eating and leaves to think.
# 2 is hungry.
# 2 starts eating
# 5 is hungry.
# 4 finishes eating and leaves to think.
# 5 starts eating
# 3 is hungry.
# 1 is hungry.
# 2 finishes eating and leaves to think.
# 3 starts eating
# 5 finishes eating and leaves to think.
# 1 starts eating
# 3 finishes eating and leaves to think.
# 1 finishes eating and leaves to think.
# 5 is hungry.
# 5 starts eating
# 5 finishes eating and leaves to think.
# 4 is hungry.
# 4 starts eating
# 2 is hungry.
# 2 starts eating
# 4 finishes eating and leaves to think.
# 3 is hungry.
# 1 is hungry.
# 1 swaps forks
# 2 finishes eating and leaves to think.
# 1 starts eating3 starts eating
#
# 4 is hungry.
# 5 is hungry.
# 5 swaps forks
# 3 finishes eating and leaves to think.
# 4 starts eating
# 1 finishes eating and leaves to think.
# 5 swaps forks
# 4 finishes eating and leaves to think.
# 5 starts eating
# 3 is hungry.
# 3 starts eating
# 2 is hungry.
# 2 swaps forks
# 4 is hungry.
# 1 is hungry.
# 3 finishes eating and leaves to think.
# 2 starts eating4 swaps forks
#
# 5 finishes eating and leaves to think.
# 4 starts eating1 swaps forks
#
# 5 is hungry.
# 2 finishes eating and leaves to think.
# 1 starts eating
# 4 finishes eating and leaves to think.
# 5 swaps forks
# 3 is hungry.
# 3 starts eating
# 1 finishes eating and leaves to think.
# 5 starts eating
# 2 is hungry.
# 2 swaps forks
# 4 is hungry.
# 3 finishes eating and leaves to think.
# 4 swaps forks
# 2 starts eating
# 2 finishes eating and leaves to think.
# 5 finishes eating and leaves to think.
# 4 starts eating
# 1 is hungry.
# 1 starts eating
# 4 finishes eating and leaves to think.
# 5 is hungry.
# 5 swaps forks
# 3 is hungry.
# 3 starts eating
# 2 is hungry.
# 1 finishes eating and leaves to think.
# 5 starts eating2 swaps forks
#
# 4 is hungry.
# 1 is hungry.
# 3 finishes eating and leaves to think.
# 2 starts eating4 swaps forks
#
# 5 finishes eating and leaves to think.
# 1 swaps forks4 starts eating
#
# 3 is hungry.
# 4 finishes eating and leaves to think.
# 2 finishes eating and leaves to think.
# 3 starts eating1 starts eating
#
# 3 finishes eating and leaves to think.
# 5 is hungry.
# 5 swaps forks
# 1 finishes eating and leaves to think.
# 5 starts eating
# 4 is hungry.
# 4 swaps forks
# 2 is hungry.
# 2 starts eating
# 5 finishes eating and leaves to think.
# 4 starts eating
# 1 is hungry.
# 1 swaps forks
# 3 is hungry.
# 2 finishes eating and leaves to think.
# 1 starts eating3 swaps forks
#
# 4 finishes eating and leaves to think.
# 3 starts eating
# 3 finishes eating and leaves to think.
# 2 is hungry.
# 1 finishes eating and leaves to think.
# 2 starts eating
# 5 is hungry.
# 5 starts eating
# 2 finishes eating and leaves to think.
# 4 is hungry.
# 4 swaps forks
# 3 is hungry.
# 3 starts eating
# 1 is hungry.
# 5 finishes eating and leaves to think.
# 4 swaps forks1 starts eating
#
# 2 is hungry.
# 3 finishes eating and leaves to think.
# 4 starts eating
# 4 finishes eating and leaves to think.
# 1 finishes eating and leaves to think.
# 2 starts eating
# 5 is hungry.
# 5 starts eating
# 2 finishes eating and leaves to think.
# 5 finishes eating and leaves to think.
# 3 is hungry.
# 3 starts eating
# 3 finishes eating and leaves to think.
# 4 is hungry.
# 4 starts eating
# 1 is hungry.
# 1 starts eating
# 5 is hungry.
# 2 is hungry.
# 4 finishes eating and leaves to think.
# 5 swaps forks
# 3 is hungry.
# 3 starts eating
# 1 finishes eating and leaves to think.
# 5 starts eating2 swaps forks
#
# 1 is hungry.
# 4 is hungry.
# 3 finishes eating and leaves to think.
# 2 starts eating4 swaps forks
#
# 5 finishes eating and leaves to think.
# 1 swaps forks4 starts eating
#
# 2 finishes eating and leaves to think.
# 1 starts eating
# 3 is hungry.
# 3 swaps forks
# 4 finishes eating and leaves to think.
# 3 starts eating
# 5 is hungry.
# 5 swaps forks
# 1 finishes eating and leaves to think.
# 5 starts eating
# 2 is hungry.
# 2 swaps forks
# 4 is hungry.
# 3 finishes eating and leaves to think.
# 2 starts eating4 swaps forks
#
# 5 finishes eating and leaves to think.
# 4 starts eating
# 1 is hungry.
# 1 swaps forks
# 3 is hungry.
# 2 finishes eating and leaves to think.
# 3 swaps forks1 starts eating
#
# 4 finishes eating and leaves to think.
# 3 starts eating
# 1 finishes eating and leaves to think.
# 2 is hungry.
# 2 swaps forks
# 5 is hungry.
# 5 starts eating
# 3 finishes eating and leaves to think.
# 2 starts eating
# 4 is hungry.
# 4 swaps forks
# 5 finishes eating and leaves to think.
# 4 starts eating
# 1 is hungry.
# 1 swaps forks
# 3 is hungry.
# 4 finishes eating and leaves to think.
# 2 finishes eating and leaves to think.
# 3 starts eating1 starts eating
#
# 2 is hungry.
# 5 is hungry.
# 5 swaps forks
# 3 finishes eating and leaves to think.
# 1 finishes eating and leaves to think.
# 2 starts eating5 starts eating
#
# 4 is hungry.
# 4 swaps forks
# 3 is hungry.
# 2 finishes eating and leaves to think.
# 3 starts eating
# 5 finishes eating and leaves to think.
# 4 swaps forks
# 5 is hungry.
# 5 starts eating
# 1 is hungry.
# 3 finishes eating and leaves to think.
# 4 swaps forks
# 2 is hungry.
# 2 starts eating
# 5 finishes eating and leaves to think.
# 4 starts eating1 swaps forks
#
# 3 is hungry.
# 2 finishes eating and leaves to think.
# 1 starts eating3 swaps forks
#
# 4 finishes eating and leaves to think.
# 3 starts eating
# 5 is hungry.
# 5 swaps forks
# 2 is hungry.
# 1 finishes eating and leaves to think.
# 5 starts eating2 swaps forks
#
# 3 finishes eating and leaves to think.
# 2 starts eating
# 5 finishes eating and leaves to think.
# 4 is hungry.
# 4 starts eating
# 5 is hungry.
# 2 finishes eating and leaves to think.
# 3 is hungry.
# 3 swaps forks
# 4 finishes eating and leaves to think.
# 3 starts eating5 starts eating
#
# 1 is hungry.
# 5 finishes eating and leaves to think.
# 1 starts eating
# 2 is hungry.
# 3 finishes eating and leaves to think.
# 1 finishes eating and leaves to think.
# 2 starts eating
# 3 is hungry.
# 4 is hungry.
# 4 starts eating
# 5 is hungry.
# 1 is hungry.
# 1 swaps forks
# 2 finishes eating and leaves to think.
# 1 starts eating3 swaps forks
#
# 4 finishes eating and leaves to think.
# 3 starts eating5 swaps forks
#
# 1 finishes eating and leaves to think.
# 5 starts eating
# 4 is hungry.
# 5 finishes eating and leaves to think.
# 1 is hungry.
# 1 starts eating
# 1 finishes eating and leaves to think.
# 5 is hungry.
# 5 starts eating
# 3 finishes eating and leaves to think.
# 4 swaps forks
# 2 is hungry.
# 2 starts eating
# 2 finishes eating and leaves to think.
# 5 finishes eating and leaves to think.
# 4 starts eating
# 1 is hungry.
# 1 starts eating
# 4 finishes eating and leaves to think.
# 3 is hungry.
# 3 starts eating
# 5 is hungry.
# 5 swaps forks
# 2 is hungry.
# 1 finishes eating and leaves to think.
# 5 starts eating2 swaps forks
#
# 4 is hungry.
# 5 finishes eating and leaves to think.
# 3 finishes eating and leaves to think.
# 2 starts eating4 starts eating
#
# 1 is hungry.
# 1 swaps forks
# 4 finishes eating and leaves to think.
# 2 finishes eating and leaves to think.
# 1 starts eating
# 5 is hungry.
# 5 swaps forks
# 4 is hungry.
# 4 starts eating
# 2 is hungry.
# 3 is hungry.
# 3 swaps forks
# 4 finishes eating and leaves to think.
# 3 starts eating
# 1 finishes eating and leaves to think.
# 2 swaps forks5 starts eating
#
# 3 finishes eating and leaves to think.
# 2 starts eating
# 5 finishes eating and leaves to think.
# 2 finishes eating and leaves to think.
# 1 is hungry.
# 1 starts eating
# 5 is hungry.
# 5 swaps forks
# 4 is hungry.
# 4 starts eating
# 3 is hungry.
# 3 swaps forks
# 4 finishes eating and leaves to think.
# 3 starts eating
# 1 finishes eating and leaves to think.
# 5 starts eating
# 1 is hungry.
# 3 finishes eating and leaves to think.
# 2 is hungry.
# 2 starts eating
# 5 finishes eating and leaves to think.
# 1 swaps forks
# 2 finishes eating and leaves to think.
# 1 starts eating
# 3 is hungry.
# 3 starts eating
# 4 is hungry.
# 3 finishes eating and leaves to think.
# 4 starts eating
# 1 finishes eating and leaves to think.
# 5 is hungry.
# 3 is hungry.
# 3 swaps forks
# 4 finishes eating and leaves to think.
# 5 starts eating
# 3 starts eating
# 5 finishes eating and leaves to think.
# 2 is hungry.
# 2 swaps forks
# 5 is hungry.
# 5 starts eating
# 1 is hungry.
# 3 finishes eating and leaves to think.
# 2 starts eating
# 4 is hungry.
# 4 swaps forks
# 3 is hungry.
# 5 finishes eating and leaves to think.
# 1 swaps forks4 starts eating
#
# 4 finishes eating and leaves to think.
# 2 finishes eating and leaves to think.
# 3 starts eating
# 1 starts eating
# 1 finishes eating and leaves to think.
# 5 is hungry.
# 5 starts eating
# 3 finishes eating and leaves to think.
# 4 is hungry.
# 4 swaps forks
# 2 is hungry.
# 2 starts eating
# 3 is hungry.
# 5 finishes eating and leaves to think.
# 4 starts eating
# 1 is hungry.
# 1 swaps forks
# 4 finishes eating and leaves to think.
# 2 finishes eating and leaves to think.
# 1 starts eating3 starts eating
#
# 1 finishes eating and leaves to think.
# 5 is hungry.
# 5 starts eating
# 3 finishes eating and leaves to think.
# 4 is hungry.
# 4 swaps forks
# 1 is hungry.
# 3 is hungry.
# 3 starts eating
# 3 finishes eating and leaves to think.
# 2 is hungry.
# 2 starts eating
# 5 finishes eating and leaves to think.
# 1 swaps forks4 starts eating
#
# 4 finishes eating and leaves to think.
# 5 is hungry.
# 5 starts eating
# 3 is hungry.
# 4 is hungry.
# 4 swaps forks
# 2 finishes eating and leaves to think.
# 1 swaps forks3 starts eating
#
# 5 finishes eating and leaves to think.
# 1 starts eating
# 4 swaps forks
# 1 finishes eating and leaves to think.
# 3 finishes eating and leaves to think.
# 4 starts eating
# 4 finishes eating and leaves to think.
# 2 is hungry.
# 2 starts eating
# 4 is hungry.
# 4 starts eating
# 3 is hungry.
# 5 is hungry.
# 1 is hungry.
# 1 swaps forks
# 2 finishes eating and leaves to think.
# 3 swaps forks1 starts eating
#
# 4 finishes eating and leaves to think.
# 3 starts eating
# 5 swaps forks
# 2 is hungry.
# 1 finishes eating and leaves to think.
# 2 swaps forks5 starts eating
#
# 4 is hungry.
# 3 finishes eating and leaves to think.
# 4 swaps forks2 starts eating
#
# 5 finishes eating and leaves to think.
# 4 starts eating
# 3 is hungry.
# 1 is hungry.
# 1 swaps forks
# 2 finishes eating and leaves to think.
# 3 swaps forks1 starts eating
#
# 5 is hungry.
# 4 finishes eating and leaves to think.
# 5 swaps forks3 starts eating
#
# 4 is hungry.
# 3 finishes eating and leaves to think.
# 4 starts eating
# 1 finishes eating and leaves to think.
# 5 swaps forks
# 4 finishes eating and leaves to think.
# 5 starts eating
# 2 is hungry.
# 2 starts eating
# 1 is hungry.
# 3 is hungry.
# 5 finishes eating and leaves to think.
# 1 swaps forks
# 2 finishes eating and leaves to think.
# 1 starts eating
# 3 starts eating
# 1 finishes eating and leaves to think.
# 4 is hungry.
# 5 is hungry.
# 5 starts eating
# 2 is hungry.
# 2 swaps forks
# 1 is hungry.
# 3 finishes eating and leaves to think.
# 4 swaps forks
# 2 starts eating
# 2 finishes eating and leaves to think.
# 5 finishes eating and leaves to think.
# 4 starts eating1 starts eating
# 3 is hungry.
# 3 swaps forks
# 2 is hungry.
# 5 is hungry.
# 1 finishes eating and leaves to think.
# 2 starts eating
# 4 finishes eating and leaves to think.
# 5 starts eating3 swaps forks
#
# 2 finishes eating and leaves to think.
# 3 starts eating
# 1 is hungry.
# 5 finishes eating and leaves to think.
# 1 starts eating
# 4 is hungry.
# 3 finishes eating and leaves to think.
# 4 starts eating
# 2 is hungry.
# 5 is hungry.
# 1 finishes eating and leaves to think.
# 2 starts eating
# 4 finishes eating and leaves to think.
# 5 starts eating
# 3 is hungry.
# 5 finishes eating and leaves to think.
# 1 is hungry.
# 1 swaps forks
# 2 finishes eating and leaves to think.
# 3 starts eating
# 1 starts eating
# 4 is hungry.
# 3 finishes eating and leaves to think.
# 4 starts eating
# 1 finishes eating and leaves to think.
# 5 is hungry.
# 4 finishes eating and leaves to think.
# 5 starts eating
# 2 is hungry.
# 2 starts eating
# 2 finishes eating and leaves to think.
# 5 finishes eating and leaves to think.
# 1 is hungry.
# 1 starts eating
# 3 is hungry.
# 3 starts eating
# 3 finishes eating and leaves to think.
# 2 is hungry.
# 4 is hungry.
# 4 starts eating
# 1 finishes eating and leaves to think.
# 2 starts eating
# 5 is hungry.
# 3 is hungry.
# 1 is hungry.
# 1 swaps forks
# 4 finishes eating and leaves to think.
# 5 starts eating
# 2 finishes eating and leaves to think.
# 1 swaps forks3 starts eating
#
# 5 finishes eating and leaves to think.
# 1 starts eating
# 4 is hungry.
# 3 finishes eating and leaves to think.
# 4 starts eating
# 2 is hungry.
# 1 finishes eating and leaves to think.
# 2 starts eating
# 2 finishes eating and leaves to think.
# 5 is hungry.
# 4 finishes eating and leaves to think.
# 5 starts eating
# 4 is hungry.
# 4 swaps forks
# 3 is hungry.
# 3 starts eating
# 5 finishes eating and leaves to think.
# 4 swaps forks
# 2 is hungry.
# 2 swaps forks
# 1 is hungry.
# 1 starts eating
# 1 finishes eating and leaves to think.
# 3 finishes eating and leaves to think.
# 4 starts eating2 starts eating
#
# 2 finishes eating and leaves to think.
# 1 is hungry.
# 1 starts eating
# 5 is hungry.
# 3 is hungry.
# 3 swaps forks
# 1 finishes eating and leaves to think.
# 2 is hungry.
# 2 starts eating
# 4 finishes eating and leaves to think.
# 3 swaps forks5 starts eating
#
# 2 finishes eating and leaves to think.
# 3 starts eating
# 5 finishes eating and leaves to think.
# 4 is hungry.
# 1 is hungry.
# 1 starts eating
# 3 finishes eating and leaves to think.
# 4 starts eating
# 4 finishes eating and leaves to think.
# 2 is hungry.
# 1 finishes eating and leaves to think.
# 2 starts eating
# 5 is hungry.
# 5 starts eating
# 3 is hungry.
# 4 is hungry.
# 4 swaps forks
# 5 finishes eating and leaves to think.
# 4 starts eating
# 4 finishes eating and leaves to think.
# 1 is hungry.
# 1 swaps forks
# 2 finishes eating and leaves to think.
# 1 starts eating
# 3 starts eating
# 4 is hungry.
# 2 is hungry.
# 3 finishes eating and leaves to think.
# 4 starts eating
# 1 finishes eating and leaves to think.
# 2 starts eating
# 4 finishes eating and leaves to think.
# 2 finishes eating and leaves to think.
# 5 is hungry.
# 5 starts eating
# 1 is hungry.
# 2 is hungry.
# 2 starts eating
# 3 is hungry.
# 2 finishes eating and leaves to think.
# 3 starts eating
# 5 finishes eating and leaves to think.
# 1 starts eating
# 4 is hungry.
# 1 finishes eating and leaves to think.
# 5 is hungry.
# 5 starts eating
# 1 is hungry.
# 2 is hungry.
# 2 swaps forks
# 3 finishes eating and leaves to think.
# 2 starts eating4 swaps forks
#
# 2 finishes eating and leaves to think.
# 5 finishes eating and leaves to think.
# 4 starts eating1 starts eating
#
# 3 is hungry.
# 3 swaps forks
# 5 is hungry.
# 2 is hungry.
# 1 finishes eating and leaves to think.
# 2 starts eating
# 4 finishes eating and leaves to think.
# 5 starts eating3 swaps forks
#
# 2 finishes eating and leaves to think.
# 3 starts eating
# 5 finishes eating and leaves to think.
# 3 finishes eating and leaves to think.
# 1 is hungry.
# 1 starts eating
# 4 is hungry.
# 4 starts eating
# 1 finishes eating and leaves to think.
# 3 is hungry.
# 3 swaps forks
# 2 is hungry.
# 2 starts eating
# 5 is hungry.
# 4 finishes eating and leaves to think.
# 3 swaps forks5 starts eating
#
# 2 finishes eating and leaves to think.
# 3 starts eating
# 1 is hungry.
# 3 finishes eating and leaves to think.
# 4 is hungry.
# 4 swaps forks
# 5 finishes eating and leaves to think.
# 4 starts eating1 starts eating
#
# 2 is hungry.
# 3 is hungry.
# 3 swaps forks
# 1 finishes eating and leaves to think.
# 2 starts eating
# 4 finishes eating and leaves to think.
# 3 swaps forks
# 5 is hungry.
# 5 starts eating
# 5 finishes eating and leaves to think.
# 1 is hungry.
# 1 swaps forks
# 2 finishes eating and leaves to think.
# 3 starts eating
# 1 starts eating
# 3 finishes eating and leaves to think.
# 1 finishes eating and leaves to think.
# 4 is hungry.
# 4 starts eating
# 4 finishes eating and leaves to think.
# 5 is hungry.
# 5 starts eating
# 1 is hungry.
# 2 is hungry.
# 2 starts eating
# 4 is hungry.
# 4 swaps forks
# 3 is hungry.
# 2 finishes eating and leaves to think.
# 3 starts eating
# 5 finishes eating and leaves to think.
# 4 swaps forks1 starts eating
#
# 3 finishes eating and leaves to think.
# 4 starts eating
# 2 is hungry.
# 5 is hungry.
# 1 finishes eating and leaves to think.
# 2 starts eating
# 4 finishes eating and leaves to think.
# 5 starts eating
# 3 is hungry.
# 1 is hungry.
# 2 finishes eating and leaves to think.
# 3 starts eating
# 4 is hungry.
# 5 finishes eating and leaves to think.
# 1 starts eating
# 3 finishes eating and leaves to think.
# 4 starts eating
# 2 is hungry.
# 3 is hungry.
# 3 swaps forks
# 4 finishes eating and leaves to think.
# 3 starts eating
# 1 finishes eating and leaves to think.
# 2 swaps forks
# 5 is hungry.
# 5 starts eating
# 4 is hungry.
# 3 finishes eating and leaves to think.
# 4 swaps forks2 starts eating
#
# 5 finishes eating and leaves to think.
# 4 starts eating
# 2 finishes eating and leaves to think.
# 1 is hungry.
# 1 starts eating
# 1 finishes eating and leaves to think.
# 4 finishes eating and leaves to think.
# 3 is hungry.
# 3 starts eating
# 1 is hungry.
# 1 starts eating
# 5 is hungry.
# 5 swaps forks
# 3 finishes eating and leaves to think.
# 2 is hungry.
# 4 is hungry.
# 4 starts eating
# 1 finishes eating and leaves to think.
# 2 starts eating5 swaps forks
#
# 2 finishes eating and leaves to think.
# 3 is hungry.
# 3 swaps forks
# 2 is hungry.
# 2 starts eating
# 4 finishes eating and leaves to think.
# 3 swaps forks
# 5 starts eating
# 1 is hungry.
# 5 finishes eating and leaves to think.
# 1 swaps forks
# 4 is hungry.
# 4 starts eating
# 2 finishes eating and leaves to think.
# 3 swaps forks
# 1 starts eating
# 4 finishes eating and leaves to think.
# 3 starts eating
# 5 is hungry.
# 5 swaps forks
# 4 is hungry.
# 1 finishes eating and leaves to think.
# 5 starts eating
# 3 finishes eating and leaves to think.
# 4 swaps forks
# 5 finishes eating and leaves to think.
# 4 starts eating
# 2 is hungry.
# 2 starts eating
# 4 finishes eating and leaves to think.
# 5 is hungry.
# 5 starts eating
# 1 is hungry.
# 3 is hungry.
# 4 is hungry.
# 4 swaps forks
# 5 finishes eating and leaves to think.
# 4 starts eating1 swaps forks
#
# 2 finishes eating and leaves to think.
# 3 swaps forks1 starts eating
#
# 4 finishes eating and leaves to think.
# 3 starts eating
# 2 is hungry.
# 5 is hungry.
# 5 swaps forks
# 1 finishes eating and leaves to think.
# 5 starts eating2 swaps forks
#
# 4 is hungry.
# 3 finishes eating and leaves to think.
# 4 swaps forks
# 2 starts eating
# 1 is hungry.
# 2 finishes eating and leaves to think.
# 5 finishes eating and leaves to think.
# 1 starts eating4 starts eating
#
# 3 is hungry.
# 3 swaps forks
# 2 is hungry.
# 4 finishes eating and leaves to think.
# 3 starts eating
# 1 finishes eating and leaves to think.
# 2 swaps forks
# 5 is hungry.
# 5 starts eating
# 3 finishes eating and leaves to think.
# 2 starts eating
# 4 is hungry.
# 4 swaps forks
# 1 is hungry.
# 5 finishes eating and leaves to think.
# 4 starts eating1 swaps forks
#
# 2 finishes eating and leaves to think.
# 1 starts eating
# 4 finishes eating and leaves to think.
# 1 finishes eating and leaves to think.
# 2 is hungry.
# 2 starts eating
# 3 is hungry.
# 5 is hungry.
# 5 starts eating
# 1 is hungry.
# 2 finishes eating and leaves to think.
# 3 starts eating
# 4 is hungry.
# 5 finishes eating and leaves to think.
# 1 starts eating
# 2 is hungry.
# 1 finishes eating and leaves to think.
# 2 swaps forks
# 3 finishes eating and leaves to think.
# 4 starts eating2 starts eating
#
# 5 is hungry.
# 2 finishes eating and leaves to think.
# 4 finishes eating and leaves to think.
# 5 starts eating
# 1 is hungry.
# 4 is hungry.
# 4 swaps forks
# 3 is hungry.
# 3 starts eating
# 5 finishes eating and leaves to think.
# 4 swaps forks1 starts eating
# 2 is hungry.
# 1 finishes eating and leaves to think.
# 2 swaps forks
# 5 is hungry.
# 5 starts eating
# 3 finishes eating and leaves to think.
# 2 starts eating4 swaps forks
#
# 5 finishes eating and leaves to think.
# 4 starts eating
# 2 finishes eating and leaves to think.
# 4 finishes eating and leaves to think.
# 5 is hungry.
# 5 starts eating
# 1 is hungry.
# 2 is hungry.
# 2 starts eating
# 3 is hungry.
# 2 finishes eating and leaves to think.
# 3 starts eating
# 5 finishes eating and leaves to think.
# 1 starts eating
# 1 finishes eating and leaves to think.
# 4 is hungry.
# 3 finishes eating and leaves to think.
# 4 starts eating
# 2 is hungry.
# 2 starts eating
# 3 is hungry.
# 2 finishes eating and leaves to think.
# 3 swaps forks
# 4 finishes eating and leaves to think.
# 3 starts eating
# 2 is hungry.
# 2 swaps forks
# 5 is hungry.
# 5 starts eating
# 4 is hungry.
# 3 finishes eating and leaves to think.
# 4 swaps forks
# 2 starts eating
# 1 is hungry.
# 5 finishes eating and leaves to think.
# 1 swaps forks4 starts eating
#
# 2 finishes eating and leaves to think.
# 1 starts eating
# 3 is hungry.
# 3 swaps forks
# 4 finishes eating and leaves to think.
# 3 starts eating
# 2 is hungry.
# 1 finishes eating and leaves to think.
# 2 swaps forks
# 5 is hungry.
# 5 starts eating
# 4 is hungry.
# 1 is hungry.
# 3 finishes eating and leaves to think.
# 4 swaps forks2 starts eating
#
# 5 finishes eating and leaves to think.
# 4 starts eating1 swaps forks
#
# 2 finishes eating and leaves to think.
# 1 starts eating
# 3 is hungry.
# 3 swaps forks
# 4 finishes eating and leaves to think.
# 3 starts eating
# 1 finishes eating and leaves to think.
# 5 is hungry.
# 5 starts eating
# 2 is hungry.
# 2 swaps forks
# 1 is hungry.
# 4 is hungry.
# 3 finishes eating and leaves to think.
# 4 swaps forks2 starts eating
#
# 5 finishes eating and leaves to think.
# 4 starts eating1 swaps forks
#
# 3 is hungry.
# 5 is hungry.
# 4 finishes eating and leaves to think.
# 5 starts eating
# 2 finishes eating and leaves to think.
# 1 swaps forks
# 3 starts eating
# 5 finishes eating and leaves to think.
# 1 starts eating
# 4 is hungry.
# 3 finishes eating and leaves to think.
# 4 starts eating
# 1 finishes eating and leaves to think.
# 1 is hungry.
# 1 starts eating
# 3 is hungry.
# 3 swaps forks
# 4 finishes eating and leaves to think.
# 3 starts eating
# 2 is hungry.
# 5 is hungry.
# 5 swaps forks
# 3 finishes eating and leaves to think.
# 1 finishes eating and leaves to think.
# 5 starts eating2 starts eating
#
# 4 is hungry.
# 4 swaps forks
# 5 finishes eating and leaves to think.
# 4 starts eating
# 2 finishes eating and leaves to think.
# 3 is hungry.
# 3 swaps forks
# 1 is hungry.
# 1 starts eating
# 4 finishes eating and leaves to think.
# 3 starts eating
# 5 is hungry.
# 5 swaps forks
# 2 is hungry.
# 1 finishes eating and leaves to think.
# 2 swaps forks5 starts eating
#
# 3 finishes eating and leaves to think.
# 2 starts eating
# 4 is hungry.
# 4 swaps forks
# 5 finishes eating and leaves to think.
# 4 starts eating
# 4 finishes eating and leaves to think.
# 2 finishes eating and leaves to think.
# 1 is hungry.
# 1 starts eating
# 1 finishes eating and leaves to think.
# 2 is hungry.
# 2 starts eating
# 3 is hungry.
# 5 is hungry.
# 5 starts eating
# 4 is hungry.
# 4 swaps forks
# 2 finishes eating and leaves to think.
# 3 starts eating
# 1 is hungry.
# 5 finishes eating and leaves to think.
# 1 starts eating
# 4 swaps forks
# 3 finishes eating and leaves to think.
# 4 starts eating
# 1 finishes eating and leaves to think.
# 2 is hungry.
# 2 starts eating
# 4 finishes eating and leaves to think.
# 1 is hungry.
# 1 swaps forks
# 2 finishes eating and leaves to think.
# 1 starts eating
# 3 is hungry.
# 3 starts eating
# 5 is hungry.
# 5 swaps forks
# 1 finishes eating and leaves to think.
# 5 starts eating
# 3 finishes eating and leaves to think.
# 2 is hungry.
# 2 starts eating
# 4 is hungry.
# 4 swaps forks
# 5 finishes eating and leaves to think.
# 4 starts eating
# 2 finishes eating and leaves to think.
# 3 is hungry.
# 3 swaps forks
# 2 is hungry.
# 2 starts eating
# 1 is hungry.
# 1 swaps forks
# 5 is hungry.
# 4 finishes eating and leaves to think.
# 3 swaps forks
# 5 starts eating
# 5 finishes eating and leaves to think.
# 4 is hungry.
# 4 starts eating
# 2 finishes eating and leaves to think.
# 1 starts eating3 swaps forks
#
# 4 finishes eating and leaves to think.
# 3 starts eating
# 1 finishes eating and leaves to think.
# 5 is hungry.
# 5 starts eating
# 1 is hungry.
# 2 is hungry.
# 2 swaps forks
# 5 finishes eating and leaves to think.
# 1 starts eating
# 3 finishes eating and leaves to think.
# 2 swaps forks
# 5 is hungry.
# 5 swaps forks
# 4 is hungry.
# 4 starts eating
# 3 is hungry.
# 3 swaps forks
# 1 finishes eating and leaves to think.
# 5 swaps forks2 starts eating
#
# 4 finishes eating and leaves to think.
# 3 swaps forks5 starts eating
#
# 2 finishes eating and leaves to think.
# 3 starts eating
# 3 finishes eating and leaves to think.
# 1 is hungry.
# 5 finishes eating and leaves to think.
# 1 starts eating
# 3 is hungry.
# 3 starts eating
# 2 is hungry.
# 1 finishes eating and leaves to think.
# 2 swaps forks
# 4 is hungry.
# 5 is hungry.
# 5 starts eating
# 3 finishes eating and leaves to think.
# 4 swaps forks2 starts eating
#
# 3 is hungry.
# 5 finishes eating and leaves to think.
# 4 starts eating
# 1 is hungry.
# 1 swaps forks
# 2 finishes eating and leaves to think.
# 3 swaps forks1 starts eating
#
# 4 finishes eating and leaves to think.
# 3 starts eating
# 5 is hungry.
# 5 swaps forks
# 1 finishes eating and leaves to think.
# 5 starts eating
# 2 is hungry.
# 2 swaps forks
# 4 is hungry.
# 3 finishes eating and leaves to think.
# 2 starts eating
# 4 swaps forks
# 1 is hungry.
# 2 finishes eating and leaves to think.
# 5 finishes eating and leaves to think.
# 1 starts eating4 starts eating
#
# 3 is hungry.
# 3 swaps forks
# 4 finishes eating and leaves to think.
# 3 starts eating
# 1 finishes eating and leaves to think.
# 4 is hungry.
# 3 finishes eating and leaves to think.
# 4 starts eating
# 5 is hungry.
# 2 is hungry.
# 2 starts eating
# 4 finishes eating and leaves to think.
# 5 starts eating
# 3 is hungry.
# 1 is hungry.
# 2 finishes eating and leaves to think.
# 3 starts eating
# 5 finishes eating and leaves to think.
# 1 starts eating
# 4 is hungry.
# 3 finishes eating and leaves to think.
# 4 starts eating
# 2 is hungry.
# 5 is hungry.
# 1 finishes eating and leaves to think.
# 2 starts eating
# 2 finishes eating and leaves to think.
# 4 finishes eating and leaves to think.
# 5 starts eating
# 3 is hungry.
# 3 starts eating
# 3 finishes eating and leaves to think.
# 1 is hungry.
# 5 finishes eating and leaves to think.
# 1 starts eating
# 2 is hungry.
# 3 is hungry.
# 3 starts eating
# 4 is hungry.
# 5 is hungry.
# 5 swaps forks
# 1 finishes eating and leaves to think.
# 5 starts eating
# 2 swaps forks
# 3 finishes eating and leaves to think.
# 4 swaps forks2 starts eating
#
# 5 finishes eating and leaves to think.
# 4 starts eating
# 3 is hungry.
# 2 finishes eating and leaves to think.
# 3 swaps forks
# 1 is hungry.
# 1 starts eating
# 1 finishes eating and leaves to think.
# 4 finishes eating and leaves to think.
# 3 starts eating
# 5 is hungry.
# 5 starts eating
# 2 is hungry.
# 2 swaps forks
# 5 finishes eating and leaves to think.
# 3 finishes eating and leaves to think.
# 2 starts eating
# 2 finishes eating and leaves to think.
# 4 is hungry.
# 4 starts eating
# 1 is hungry.
# 1 starts eating
# 4 finishes eating and leaves to think.
